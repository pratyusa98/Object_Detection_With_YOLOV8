# %% [markdown]
# First Change Run Time In GPU
#
# Then Mount the Google Drive
#
# Then !pip install ultralytics

# %%
# !nvidia-smi
# Out:
# Sat Mar 11 18:39:41 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   64C    P0    32W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !pip install ultralytics
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 496.3/496.3 KB 29.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 KB 15.8 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

# %% [markdown]
# # **Custom Train YOLO Model**
#
# Here In Data Gives data.yaml file

# %%
# !yolo task=detect mode=train model=yolov8l.pt data='/content/drive/MyDrive/Colab Notebooks/dataset/apple/data.yaml' epochs=50 imgsz=640 batch=8
# Out:
# Ultralytics YOLOv8.0.52 🚀 Python-3.8.10 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# After Succefully Run Download Best.pt file and use in local prediction

# %% [markdown]
# ## **Custom Predict**

# %%
# !yolo task=detect mode=predict model=yolov8l.pt conf=0.25 source='https://www.gannett-cdn.com/presto/2018/12/23/PASH/22245ea0-8803-43b1-aadf-cf77a6993502-WolfRidgeSki_12222018_0409.jpg' save=True
# Out:
# ...
# 100% 83.7M/83.7M [00:00<00:00, 348MB/s]
# Ultralytics YOLOv8.0.52 🚀 Python-3.9.16 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8l summary (fused): 268 layers, 43668288 parameters, 0 gradients, 165.2 GFLOPs
#
# ...
# 100% 168k/168k [00:00<00:00, 48.9MB/s]
# image 1/1 /content/22245ea0-8803-43b1-aadf-cf77a6993502-WolfRidgeSki_12222018_0409.jpg: 640x448 4 persons, 1 skis, 1 snowboard, 47.6ms
# Speed: 0.6ms preprocess, 47.6ms inference, 41.0ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict
